# %% [markdown]
# # Training with Small sample dataset as demo

# %% [markdown]
# ## 1. Unzip sample dataset

# %%
# %cd data
# Out:
# /home/kang/SAR_OD/anonymous-hub/SAROD/data

# %%
# !bash download_for_Demo.sh
# Out:
# download_for_Demo.sh: line 2: $'\r': command not found
# --2020-10-06 08:13:12--  https://docs.google.com/uc?export=download&confirm=WeOp&id=1TIhupsTTtdPHjFzYTVejLyyPo9UzrSk3
# Resolving docs.google.com (docs.google.com)... 172.217.175.238, 2404:6800:4004:811::200e
# Connecting to docs.google.com (docs.google.com)|172.217.175.238|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-a0-docs.googleusercontent.com/docs/securesc/to96720jq15e9obcjv3e2ugee26amu92/s40tcvesma7qe6bn0c8jmvg66sv076qf/1601971950000/11079565382010845860/17347132251095186972Z/1TIhupsTTtdPHjFzYTVejLyyPo9UzrSk3?e=download [following]
# --2020-10-06 08:13:13--  https://doc-04-a0-docs.googleusercontent.com/docs/securesc/to96720jq15e9obcjv3e2ugee26amu92/s40tcvesma7qe6bn0c8jmvg66sv076qf/1601971950000/11079565382010845860/17347132251095186972Z/1TIhupsTTtdPHjFzYTVejLyyPo9UzrSk3?e=download
# ...

# %%
# !unzip sample.zip
# Out:
# Archive:  sample.zip
#    creating: dt_ver/
#    creating: dt_ver/test/
#    creating: dt_ver/test/images/
#   inflating: dt_ver/test/images/P0001_0_800_10190_10990_0.jpg
#   inflating: dt_ver/test/images/P0001_1200_2000_10190_10990_0.jpg
#   inflating: dt_ver/test/images/P0001_1200_2000_10190_10990_2.jpg
#   inflating: dt_ver/test/images/P0001_1200_2000_3600_4400_1.jpg
#   inflating: dt_ver/test/images/P0001_1200_2000_3600_4400_2.jpg
#   inflating: dt_ver/test/images/P0001_1800_2600_0_800_0.jpg
#   inflating: dt_ver/test/images/P0001_1800_2600_0_800_1.jpg
#   inflating: dt_ver/test/images/P0001_1800_2600_7800_8600_1.jpg
#   inflating: dt_ver/test/images/P0001_2400_3200_4800_5600_0.jpg
#   inflating: dt_ver/test/images/P0001_2400_3200_4800_5600_1.jpg
#   inflating: dt_ver/test/images/P0001_2400_3200_4800_5600_2.jpg
#   inflating: dt_ver/test/images/P0001_2400_3200_4800_5600_3.jpg
#   inflating: dt_ver/test/images/P0001_3000_3800_2400_3200_2.jpg
# ...

# %%
# %cd ..
# Out:
# /home/kang/SAR_OD/anonymous-hub/SAROD

# %% [markdown]
# ## 2. training with sample dataset, small batch

# %%
# !python train.py --epochs 10\
--detector_batch_size 4\
--device 2\
--test_epoch 1\
--eval_epoch 1\
--step_batch_size 2\
--save_path save
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# GPU device for EfficientOD:  True
# Your branch is behind 'origin/main' by 2 commits, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
#
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# {'cfg': 'yolov5/models/yolov5x_custom.yaml', 'data': 'yolov5/data/HRSID_800_od.yaml', 'hyp': '', 'epochs': 10, 'batch_size': 4, 'img_size': [480, 480], 'rect': False, 'resume': False, 'nosave': False, 'notest': True, 'noautoanchor': True, 'evolve': False, 'bucket': '', 'cache_images': True, 'weights': ' ', 'name': 'yolov5x_800_480_200epoch', 'device': '2', 'multi_scale': False, 'single_cls': True, 'sync_bn': False, 'local_rank': -1, 'total_batch_size': 4, 'world_size': 1}
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# ...
