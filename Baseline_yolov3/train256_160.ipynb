# %%
# !python train.py --epochs 500 --batch_size 16 --model_def config/yolov3-custom.cfg --data_config config/custom.data --img_size 160 --pretrained_weights checkpoints/yolov3_ckpt_553.pth
# Out:
# Namespace(batch_size=16, checkpoint_interval=1, compute_map=False, data_config='config/custom.data', epochs=500, evaluation_interval=1, gradient_accumulations=2, img_size=160, model_def='config/yolov3-custom.cfg', multiscale_training=True, n_cpu=8, pretrained_weights='checkpoints/yolov3_ckpt_553.pth')
#
# ---- [Epoch 0/500, Batch 247/248] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 0.028030     | 0.042138     | 0.073158     |
# | x          | 0.002603     | 0.003573     | 0.011621     |
# | y          | 0.006137     | 0.005168     | 0.016022     |
# | w          | 0.010910     | 0.007867     | 0.008031     |
# | h          | 0.007422     | 0.007902     | 0.004215     |
# | conf       | 0.000958     | 0.017627     | 0.033269     |
# ...

# %%
# !python test.py --weights_path checkpoints/yolov3_ckpt_499.pth --model_def config/yolov3-custom.cfg --data_config config/custom.data
# Out:
# Namespace(batch_size=8, class_path='data/coco.names', conf_thres=0.001, data_config='config/custom.data', img_size=416, iou_thres=0.5, model_def='config/yolov3-custom.cfg', n_cpu=8, nms_thres=0.5, weights_path='checkpoints/yolov3_ckpt_499.pth')
# Compute mAP...
# ...
# Computing AP: 100%|██████████████████████████████| 1/1 [00:00<00:00, 155.95it/s]
# Average Precisions:
# + Class '0' (ship) - AP: 0.9201662861652863
# mAP: 0.9201662861652863

# %%
# !python test160.py --weights_path checkpoints/yolov3_ckpt_499.pth --model_def config/yolov3-custom.cfg --data_config config/custom.data --img_size=256
# Out:
# Namespace(batch_size=8, class_path='data/coco.names', conf_thres=0.001, data_config='config/custom.data', img_size=256, iou_thres=0.5, model_def='config/yolov3-custom.cfg', n_cpu=8, nms_thres=0.5, weights_path='checkpoints/yolov3_ckpt_499.pth')
# Compute mAP...
# Detecting objects:   0%|                                | 0/584 [00:00<?, ?it/s]/home/cutz/SAR_OD/PyTorch-YOLOv3-master/utils/datasets.py:107: UserWarning: loadtxt: Empty input file: "/media/data2/dataset/SSDD/256/Test/160/labels/ship02016072901030024_1.txt"
#   boxes = torch.from_numpy(np.loadtxt(label_path).reshape(-1, 5))
# /home/cutz/SAR_OD/PyTorch-YOLOv3-master/utils/datasets.py:107: UserWarning: loadtxt: Empty input file: "/media/data2/dataset/SSDD/256/Test/160/labels/ship02017050701039036_2.txt"
#   boxes = torch.from_numpy(np.loadtxt(label_path).reshape(-1, 5))
# ...
