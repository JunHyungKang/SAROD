# %%
# !python make_detect_info.py --weights_path checkpoints480/yolov3_ckpt_999.pth --model_def config/yolov3-custom480.cfg \
--data_config config/custom480_rl.data \
--img_size=480 --batch_size 1 --class_path data/custom480/classes.names \
--save_dir /home/cutz/SAR_OD/EfficientObjectDetection/data/800/base_dir_detections_fd
# Out:
# Namespace(batch_size=1, class_path='data/custom480/classes.names', conf_thres=0.001, data_config='config/custom480_rl.data', img_size=480, iou_thres=0.5, model_def='config/yolov3-custom480.cfg', n_cpu=8, nms_thres=0.5, save_dir='/home/cutz/SAR_OD/EfficientObjectDetection/data/800/base_dir_detections_fd', weights_path='checkpoints480/yolov3_ckpt_999.pth')
# Compute mAP...
# Detecting objects:   0%|                       | 1/1308 [00:00<19:19,  1.13it/s]/home/cutz/SAR_OD/PyTorch-YOLOv3-master/utils/datasets.py:107: UserWarning: loadtxt: Empty input file: "/media/data2/dataset/SSDD/800/train_rl/480/labels/P0014_3000_3800_3000_3800_3.txt"
#   boxes = torch.from_numpy(np.loadtxt(label_path).reshape(-1, 5))
# Detecting objects:   0%|                       | 5/1308 [00:01<13:42,  1.58it/s]/home/cutz/SAR_OD/PyTorch-YOLOv3-master/utils/datasets.py:107: UserWarning: loadtxt: Empty input file: "/media/data2/dataset/SSDD/800/train_rl/480/labels/P0048_1200_2000_7300_8100_3.txt"
# ...
