# %%
# !python SAR_slice_800.py -d /media/data2/dataset/SSDD/800/HRSID-master/data/HRSID_JPG/HRSID_JPG/train/ -w 480 -s 320
# Out:
# New image saved : P0049_0_800_4800_5600_0
# New Annotation with object saved : P0049_0_800_4800_5600_0
# No object found in : P0049_0_800_4800_5600_1
# No object found in : P0049_0_800_4800_5600_1
# No object found in : P0049_0_800_4800_5600_1
# No object found in : P0071_1800_2600_3600_4400_0
# No object found in : P0071_1800_2600_3600_4400_0
# New image saved : P0071_1800_2600_3600_4400_0
# New Annotation with object saved : P0071_1800_2600_3600_4400_0
# No object found in : P0071_1800_2600_3600_4400_1
# No object found in : P0063_3000_3800_4800_5600_0
# No object found in : P0063_3000_3800_4800_5600_0
# No object found in : P0063_3000_3800_4800_5600_0
# New image saved : P0063_3000_3800_4800_5600_0
# New Annotation with object saved : P0063_3000_3800_4800_5600_0
# No object found in : P0065_600_1400_5901_6701_0
# No object found in : P0065_600_1400_5901_6701_0
# No object found in : P0065_600_1400_5901_6701_0
# New image saved : P0065_600_1400_5901_6701_0
# ...
