# %%
# !python train.py \
--epochs 200 \
--batch_size 40 \
--device 0 \
--test_epoch 10 \
--eval_epoch 1 \
--split 4 \
--split_train_path '/home/SSDD/ICIP21_dataset/800_HRSID/split_data_4_0/rl_ver/sample/images' \
--split_val_path '/home/SSDD/ICIP21_dataset/800_HRSID/split_data_4_0/rl_ver/sample/images' \
--split_test_path '/home/SSDD/ICIP21_dataset/800_HRSID/split_data_4_0/rl_ver/sample/images' \
--original_img_path_train '/home/SSDD/ICIP21_dataset/800_HRSID/origin_data/rl_ver/sample/images' \
--original_img_path_val '/home/SSDD/ICIP21_dataset/800_HRSID/origin_data/rl_ver/sample/images' \
--original_img_path_test '/home/SSDD/ICIP21_dataset/800_HRSID/origin_data/rl_ver/sample/images'
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  yolov5.models.common.Focus              [3, 80, 3]
#   1                -1  1    115520  yolov5.models.common.Conv               [80, 160, 3, 2]
#   2                -1  1    315680  yolov5.models.common.BottleneckCSP      [160, 160, 4]
#   3                -1  1    461440  yolov5.models.common.Conv               [160, 320, 3, 2]
#   4                -1  1   3311680  yolov5.models.common.BottleneckCSP      [320, 320, 12]
#   5                -1  1   1844480  yolov5.models.common.Conv               [320, 640, 3, 2]
#   6                -1  1  13228160  yolov5.models.common.BottleneckCSP      [640, 640, 12]
#   7                -1  1   7375360  yolov5.models.common.Conv               [640, 1280, 3, 2]
#   8                -1  1   4099840  yolov5.models.common.SPP                [1280, 1280, [5, 9, 13]]
#   9                -1  1  20087040  yolov5.models.common.BottleneckCSP      [1280, 1280, 4, False]
#  10                -1  1    820480  yolov5.models.common.Conv               [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  yolov5.models.common.Concat             [1]
#  13                -1  1   5435520  yolov5.models.common.BottleneckCSP      [1280, 640, 4, False]
#  14                -1  1    205440  yolov5.models.common.Conv               [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  yolov5.models.common.Concat             [1]
#  17                -1  1   1360960  yolov5.models.common.BottleneckCSP      [640, 320, 4, False]
#  18                -1  1    922240  yolov5.models.common.Conv               [320, 320, 3, 2]
#  19          [-1, 14]  1         0  yolov5.models.common.Concat             [1]
#  20                -1  1   5025920  yolov5.models.common.BottleneckCSP      [640, 640, 4, False]
#  21                -1  1   3687680  yolov5.models.common.Conv               [640, 640, 3, 2]
#  22          [-1, 10]  1         0  yolov5.models.common.Concat             [1]
#  23                -1  1  20087040  yolov5.models.common.BottleneckCSP      [1280, 1280, 4, False]
#  24      [17, 20, 23]  1     40374  yolov5.models.yolo.Detect               [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280]]
#
# Optimizer groups: 134 .bias, 142 conv.weight, 131 other
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  yolov5.models.common.Focus              [3, 80, 3]
#   1                -1  1    115520  yolov5.models.common.Conv               [80, 160, 3, 2]
#   2                -1  1    315680  yolov5.models.common.BottleneckCSP      [160, 160, 4]
#   3                -1  1    461440  yolov5.models.common.Conv               [160, 320, 3, 2]
#   4                -1  1   3311680  yolov5.models.common.BottleneckCSP      [320, 320, 12]
#   5                -1  1   1844480  yolov5.models.common.Conv               [320, 640, 3, 2]
#   6                -1  1  13228160  yolov5.models.common.BottleneckCSP      [640, 640, 12]
#   7                -1  1   7375360  yolov5.models.common.Conv               [640, 1280, 3, 2]
#   8                -1  1   4099840  yolov5.models.common.SPP                [1280, 1280, [5, 9, 13]]
#   9                -1  1  20087040  yolov5.models.common.BottleneckCSP      [1280, 1280, 4, False]
#  10                -1  1    820480  yolov5.models.common.Conv               [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  yolov5.models.common.Concat             [1]
#  13                -1  1   5435520  yolov5.models.common.BottleneckCSP      [1280, 640, 4, False]
#  14                -1  1    205440  yolov5.models.common.Conv               [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  yolov5.models.common.Concat             [1]
#  17                -1  1   1360960  yolov5.models.common.BottleneckCSP      [640, 320, 4, False]
#  18                -1  1    922240  yolov5.models.common.Conv               [320, 320, 3, 2]
#  19          [-1, 14]  1         0  yolov5.models.common.Concat             [1]
#  20                -1  1   5025920  yolov5.models.common.BottleneckCSP      [640, 640, 4, False]
#  21                -1  1   3687680  yolov5.models.common.Conv               [640, 640, 3, 2]
#  22          [-1, 10]  1         0  yolov5.models.common.Concat             [1]
#  23                -1  1  20087040  yolov5.models.common.BottleneckCSP      [1280, 1280, 4, False]
#  24      [17, 20, 23]  1     40374  yolov5.models.yolo.Detect               [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280]]
#
# Optimizer groups: 134 .bias, 142 conv.weight, 131 other
# GPU device for EfficientOD:  True
# Scanning images: 100%|██████████████████████| 240/240 [00:00<00:00, 1061.81it/s]
# Scanning labels /home/SSDD/ICIP21_dataset/800_HRSID/split_data_4_0/rl_ver/sample
# Scanning labels /home/SSDD/ICIP21_dataset/800_HRSID/split_data_4_0/rl_ver/sample
# Starting training for 0 epochs...
# 100%|█████████████████████████████████████████████| 5/5 [00:39<00:00,  7.89s/it]
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.75s/it]
# len(fine_dataset.tolist()):
#  132
# Scanning images: 100%|██████████████████████| 132/132 [00:00<00:00, 1218.29it/s]
# Scanning labels /home/SSDD/ICIP21_dataset/800_HRSID/split_data_4_0/rl_ver/sample
# 100%|█████████████████████████████████████████████| 3/3 [00:02<00:00,  1.37it/s]
# len(coarse_dataset.tolist()):
#  108
# Scanning images: 100%|██████████████████████| 108/108 [00:00<00:00, 1219.87it/s]
# Scanning labels /home/SSDD/ICIP21_dataset/800_HRSID/split_data_4_0/rl_ver/sample
#  40%|██████████████████                           | 2/5 [00:01<00:02,  1.26it/s]
# Validation mAP:
#  1.2934379580926102e-06
# Time for validation:
#  4.883749008178711
# Starting training for 1 epochs...
#   0%|                                                     | 0/5 [00:00<?, ?it/s]^C
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f1deec267a0>
# Traceback (most recent call last):
#   File "/home/kang/anaconda3/envs/SAROD/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/home/kang/anaconda3/envs/SAROD/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/kang/anaconda3/envs/SAROD/lib/python3.7/multiprocessing/process.py", line 140, in join
#     res = self._popen.wait(timeout)
#   File "/home/kang/anaconda3/envs/SAROD/lib/python3.7/multiprocessing/popen_fork.py", line 45, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/kang/anaconda3/envs/SAROD/lib/python3.7/multiprocessing/connection.py", line 921, in wait
#     ready = selector.select(timeout)
#   File "/home/kang/anaconda3/envs/SAROD/lib/python3.7/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
