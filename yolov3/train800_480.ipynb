# %%
# !python train800.py --epochs 1000 --batch_size 24 --model_def config/yolov3-custom480.cfg --data_config config/custom480.data --img_size 480
# Out:
# GPU device  True
# Namespace(batch_size=24, checkpoint_interval=1, compute_map=False, data_config='config/custom480.data', epochs=1000, evaluation_interval=1, gradient_accumulations=2, img_size=480, model_def='config/yolov3-custom480.cfg', multiscale_training=True, n_cpu=8, pretrained_weights=None)
# ^C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     160                 # know whether we've finished (if we matched EOF) or not
# --> 161                 res_idx = child.expect_list(patterns, self.read_timeout)
#     162                 print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371         else:
# ...

# %%
# !python test.py --weights_path checkpoints480/yolov3_ckpt_999.pth --model_def config/yolov3-custom480.cfg --data_config config/custom480.data --img_size 480
# Out:
# GPU device  True
# Namespace(batch_size=8, class_path='data/coco.names', conf_thres=0.001, data_config='config/custom480.data', img_size=480, iou_thres=0.5, model_def='config/yolov3-custom480.cfg', n_cpu=8, nms_thres=0.5, weights_path='checkpoints480/yolov3_ckpt_999.pth')
# Compute mAP...
# Detecting objects:   0%|                                | 0/973 [00:00<?, ?it/s]/home/cutz/SAR_OD/PyTorch-YOLOv3-master/utils/datasets.py:107: UserWarning: loadtxt: Empty input file: "/media/data2/dataset/SSDD/800/test/480/labels/P0038_3000_3800_2400_3200_0.txt"
#   boxes = torch.from_numpy(np.loadtxt(label_path).reshape(-1, 5))
# /home/cutz/SAR_OD/PyTorch-YOLOv3-master/utils/datasets.py:107: UserWarning: loadtxt: Empty input file: "/media/data2/dataset/SSDD/800/test/480/labels/P0075_0_800_600_1400_3.txt"
#   boxes = torch.from_numpy(np.loadtxt(label_path).reshape(-1, 5))
# ...
