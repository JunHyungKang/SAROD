# %%
# YOLOv5 baseline (960 x 960) - 200 epoch / 8 batch / original images
# !python train.py
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Namespace(batch_size=8, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='3', epochs=200, evolve=False, hyp='', img_size=[960, 960], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=8, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...

# %%
# YOLOv5 baseline (192 x 192) - 200 epoch / 8 batch / original images
# !python train.py
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Namespace(batch_size=8, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='3', epochs=200, evolve=False, hyp='', img_size=[192, 192], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=8, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...

# %%
# YOLOv5 baseline (192 x 192) - 100 epoch / 8 batch / original images
# !python train.py
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Namespace(batch_size=8, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='3', epochs=100, evolve=False, hyp='', img_size=[192, 192], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=8, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...

# %%
# YOLOv5 baseline (960 x 960) - 100 epoch / 8 batch / original images
# !python train.py
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Namespace(batch_size=8, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='3', epochs=100, evolve=False, hyp='', img_size=[960, 960], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=8, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...

# %%
# YOLOv5 baseline (480 x 480) - 200 epoch / 32 batch size / original images
# GPU: 3
# !python train.py
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Namespace(batch_size=32, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='3', epochs=200, evolve=False, hyp='', img_size=[480, 480], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=32, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...

# %%
# YOLOv5 baseline (480 x 480) - 50 epoch / 32 batch size / original images
# GPU: 3
# !python train.py
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Namespace(batch_size=32, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='3', epochs=50, evolve=False, hyp='', img_size=[480, 480], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=32, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...

# %%
# YOLOv5 baseline (480 x 480) - 30 epoch / 32 batch size / cropped images - trian
# GPU: 3
# !python train.py
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Namespace(batch_size=32, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='3', epochs=30, evolve=False, hyp='', img_size=[480, 480], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=32, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...

# %%
# YOLOv5 baseline (480 x 480) - 30 epoch / 32 batch size / cropped images - test
# GPU: 3
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_30epoch_cropped/weights/last.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 32 \
--img-size 480 \
--task 'test' \
--device 3
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='3', img_size=480, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_30epoch_cropped/weights/last.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all    7.85e+03    7.88e+03       0.517       0.865       0.823       0.568
# Speed: 5.6/1.1/6.7 ms inference/NMS/total per 480x480 image at batch-size 32

# %%
# YOLOv5 baseline (96 x 96) - 30 epoch / 32 batch size / cropped images - trian
# GPU: 3
# !python train.py --data data/HRSID_800.yaml \
--epochs 30 \
--batch-size 32 \
--img-size 96 \
--device 3
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Namespace(batch_size=32, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='3', epochs=30, evolve=False, hyp='', img_size=[96, 96], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=32, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...

# %%
# YOLOv5 baseline (96 x 96) - 30 epoch / 32 batch size / cropped images - test
# GPU: 3
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_30epoch_cropped/weights/last.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 32 \
--img-size 96 \
--task 'test' \
--device 3
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='3', img_size=96, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_30epoch_cropped/weights/last.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all    7.85e+03    7.88e+03       0.359        0.25       0.202      0.0456
# Speed: 0.8/0.7/1.6 ms inference/NMS/total per 96x96 image at batch-size 32

# %%
# YOLOv5 baseline (480 x 480) - 50 epoch / 32 batch size / cropped images - trian
# GPU: 3
# !python train.py --data data/HRSID_800.yaml \
--epochs 50 \
--batch-size 32 \
--img-size 480 \
--device 3
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Namespace(batch_size=32, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='3', epochs=50, evolve=False, hyp='', img_size=[480, 480], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=32, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...

# %%
# YOLOv5 baseline (96 x 96) - 30 epoch / 32 batch size / cropped images - test
# GPU: 3
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_50epoch_cropped/weights/last.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 32 \
--img-size 480 \
--task 'test' \
--device 3
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='3', img_size=480, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_50epoch_cropped/weights/last.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all    7.85e+03    7.88e+03       0.538       0.871       0.829       0.579
# Speed: 5.5/1.3/6.9 ms inference/NMS/total per 480x480 image at batch-size 32

# %%
# YOLOv5 baseline (96 x 96) - 50 epoch / 32 batch size / cropped images - trian
# GPU: 3
# !python train.py --data data/HRSID_800.yaml \
--epochs 50 \
--batch-size 32 \
--img-size 96 \
--device 3
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Namespace(batch_size=32, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='3', epochs=50, evolve=False, hyp='', img_size=[96, 96], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=32, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...

# %%
# YOLOv5 baseline (96 x 96) - 50 epoch / 32 batch size / cropped images - test
# GPU: 3
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_50epoch_cropped/weights/last.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 32 \
--img-size 96 \
--task 'test' \
--device 3
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='3', img_size=96, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_50epoch_cropped/weights/last.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all    7.85e+03    7.88e+03      0.0609       0.246      0.0324     0.00966
# Speed: 0.8/1.3/2.1 ms inference/NMS/total per 96x96 image at batch-size 32

# %%
# YOLOv5 baseline (96 x 96) - 50 epoch / 32 batch size / cropped images - test
# GPU: 3
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_50epoch_cropped/weights/best.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 32 \
--img-size 96 \
--task 'test' \
--device 3
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='3', img_size=96, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_50epoch_cropped/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all    7.85e+03    7.88e+03      0.0465       0.236      0.0243     0.00758
# Speed: 1.2/1.7/2.9 ms inference/NMS/total per 96x96 image at batch-size 32

# %%
# YOLOv5 baseline (96 x 96) - 50 epoch / 32 batch size / cropped images - test
# GPU: 3
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_50epoch_cropped/weights/best.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 1 \
--img-size 480 \
--task 'test' \
--device 3
# Out:
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='3', img_size=480, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_50epoch_cropped/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all    7.85e+03    7.88e+03       0.543        0.87        0.83       0.585
# Speed: 43.7/6.9/50.5 ms inference/NMS/total per 480x480 image at batch-size 1

# %%
# YOLOv5 baseline (96 x 96) - 50 epoch / 32 batch size / cropped images - test
# GPU: 3
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_50epoch_cropped/weights/best.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 1 \
--img-size 96 \
--task 'test' \
--device 2
# Out:
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='2', img_size=96, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_50epoch_cropped/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all    7.85e+03    7.88e+03      0.0465       0.236      0.0243     0.00758
# Speed: 28.1/1.7/29.8 ms inference/NMS/total per 96x96 image at batch-size 1
#
# time: 291.71200370788574

# %%
# YOLOv5 baseline (96 x 96) - 50 epoch / 32 batch size / cropped images - test
# GPU: 3
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_50epoch_cropped/weights/best.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 1 \
--img-size 480 \
--task 'test' \
--device 3
# Out:
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='3', img_size=480, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_50epoch_cropped/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800_debug/time/test/labels.ca
#                Class      Images     Targets           P           R      mAP@.5
#                  all           4           3       0.772           1       0.995       0.599
# Speed: 43.3/8.3/51.6 ms inference/NMS/total per 480x480 image at batch-size 1
#
# time: 6.982495307922363

# %%
# time check - 480 fine detector (89 % of data) - 324, 279, 306, 
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_50epoch_cropped/weights/best.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 1 \
--img-size 480 \
--task 'test' \
--device 2
# Out:
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='2', img_size=480, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_50epoch_cropped/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all    6.98e+03    7.19e+03       0.532       0.873       0.828       0.579
# Speed: 31.4/1.6/33.0 ms inference/NMS/total per 480x480 image at batch-size 1
#
# time: 306.70431089401245

# %%
# time check - 480 fine detector (11 % of data) - 324.06, 
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_50epoch_cropped/weights/best.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 1 \
--img-size 96 \
--task 'test' \
--device 2
# Out:
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='2', img_size=96, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_50epoch_cropped/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all         863         753      0.0589       0.348      0.0449      0.0143
# Speed: 29.0/1.7/30.7 ms inference/NMS/total per 96x96 image at batch-size 1
#
# time: 39.718384981155396

# %%
# time check - 480 fine detector (100 % of data) - 319, 
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_50epoch_cropped/weights/best.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 1 \
--img-size 480 \
--task 'test' \
--device 2
# Out:
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='2', img_size=480, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/480size_50epoch_cropped/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all    7.85e+03    7.88e+03       0.543        0.87        0.83       0.585
# Speed: 35.4/1.7/37.1 ms inference/NMS/total per 480x480 image at batch-size 1
#
# time: 387.35008430480957

# %%
# time check - 96 fine detector (100 % of data)
# !python test.py  --weights /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_50epoch_cropped/weights/best.pt \
--data /home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml \
--batch-size 1 \
--img-size 96 \
--task 'test' \
--device 2
# Out:
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/data/HRSID_800.yaml', device='2', img_size=96, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/EfficientOD_WACV/yolov5-baseline/runs/96size_50epoch_cropped/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Graphics Device', total_memory=24190MB)
#
# Fusing layers... Model Summary: 284 layers, 8.83906e+07 parameters, 8.45317e+07 gradients
# Scanning labels /media/data2/dataset/SSDD/800/ICPR_800/rl_ver/test/labels.cache
#                Class      Images     Targets           P           R      mAP@.5
#                  all    7.85e+03    7.88e+03      0.0465       0.236      0.0243     0.00758
# Speed: 24.3/1.5/25.8 ms inference/NMS/total per 96x96 image at batch-size 1
#
# time: 256.4498336315155

# %%
# !python test.py  --weights /home/kang/SAR_OD/anonymous-hub/SAROD/weights/last.pt \
--data /home/kang/SAR_OD/anonymous-hub/SAROD/Baseline_yolov5/data/HRSID_800.yaml \
--batch-size 1 \
--img-size 480 \
--task 'test' \
--device 0
# Out:
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='/home/kang/SAR_OD/anonymous-hub/SAROD/Baseline_yolov5/data/HRSID_800.yaml', device='0', img_size=480, iou_thres=0.65, merge=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['/home/kang/SAR_OD/anonymous-hub/SAROD/weights/last.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='TITAN RTX', total_memory=24190MB)
#
# /home/kang/anaconda3/envs/ai/lib/python3.8/site-packages/torch/serialization.py:649: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ...

# %%
# !pwd
# Out:
# /home/kang/SAR_OD/anonymous-hub/SAROD/Baseline_yolov5

# %%
# !python train.py --data data/HRSID_800.yaml \
--epochs 60 \
--batch-size 32 \
--img-size 480 \
--device 0
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Using CUDA device0 _CudaDeviceProperties(name='TITAN RTX', total_memory=24190MB)
#
# Namespace(batch_size=32, bucket='', cache_images=False, cfg='models/yolov5x.yaml', data='data/HRSID_800.yaml', device='0', epochs=60, evolve=False, hyp='', img_size=[480, 480], local_rank=-1, multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=32, weights='', world_size=1)
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Hyperparameters {'optimizer': 'SGD', 'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# ...
